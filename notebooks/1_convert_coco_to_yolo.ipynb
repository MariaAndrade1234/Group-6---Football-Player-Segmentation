# %%
# %% [markdown]
# # Conversão de COCO para YOLO
# 
# Este notebook converte suas anotações no formato COCO JSON para o formato YOLOv8

# %%
import json
from scripts.convert_coco_to_yolo import convert_coco_to_yolo
import os

# Configurações
coco_json_path = "../annotations/instances_default.json"
images_dir = "../data/images"
output_dir = "../data/yolo_dataset"

# %%
# Executar conversão
convert_coco_to_yolo(coco_json_path, images_dir, output_dir)

# %%
# Verificar estrutura criada
print("Estrutura criada:")
# !tree {output_dir} -L 3
